# %% [markdown]
# # Text Prompt Design: Challenge Lab
#
# ## Overview
#
# This challenge lab is designed to test your knowledge of calling Gemini and utilizing a few fundamental text prompt design techniques.
#
# Two featured guides on prompting from the Google Cloud documentation are:
#
# 1. [Overview of prompting strategies](https://cloud.google.com/vertex-ai/generative-ai/docs/learn/prompts/prompt-design-strategies) from the Generative AI on Gen AI documentation.
#
# 2. [Prompt design strategies](https://ai.google.dev/gemini-api/docs/prompting-strategies) from the Gemini API documentation.
#
# Both contain good tips. You are encouraged to **bookmark them**.
#
# ## Objective
# You will demonstrate your ability to:
#
# - Initialize Gen AI in your environment
# - Load a generative model
# - Guide model output with a persona
# - Extract information to a schema
# - Stay on topic with fallback responses
# - Use examples to influence the model's response
#
# Some of the following Python notebook cells have missing or incomplete code sections and tasks that need to be completed, indicated by the code comments starting with `# TODO`. Your challenge is to complete each cell, run it to test for correctness, and then move on. When all the cells are working, you have completed the challenge.
#
# **Note:** If you need help, [this notebook demonstrates getting started using Gemini in Python](https://github.com/GoogleCloudPlatform/generative-ai/blob/main/gemini/getting-started/intro_gemini_python.ipynb).

# %% [markdown]
# ## Task 1. Install, import & initialize the Gen AI SDK and a generative model
#
# 1. Install the Gen AI SDK.

# %%
# TODO: Complete the following pip command
# %pip install --upgrade --user google-cloud-aiplatform
# Out:
# Requirement already satisfied: google-cloud-aiplatform in /opt/conda/lib/python3.10/site-packages (1.95.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.24.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (3.20.3)
# Requirement already satisfied: packaging>=14.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (24.2)
# Requirement already satisfied: google-cloud-storage<3.0.0,>=1.32.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (3.31.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.14.2)
# Requirement already satisfied: shapely<3.0.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.0.7)
# Requirement already satisfied: google-genai<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.17.0)
# Requirement already satisfied: pydantic<3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.11.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (4.13.0)
# Requirement already satisfied: docstring-parser<1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (0.16)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.69.2)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /opt/conda/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.49.0rc1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.7.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-resource-manager<3.0.0,>=1.3.3->google-cloud-aiplatform) (0.14.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage<3.0.0,>=1.32.0->google-cloud-aiplatform) (1.7.1)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (4.9.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /opt/conda/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (0.28.1)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (15.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform) (0.4.0)
# Requirement already satisfied: numpy<3,>=1.14 in /opt/conda/lib/python3.10/site-packages (from shapely<3.0.0->google-cloud-aiplatform) (2.1.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (1.3.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (0.16.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform) (0.6.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.26.20)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 2. Restart your notebook kernel.
# 3. Import the following:
# - the Gen AI SDK
# - the class to instantiate a generative model from the Gen AI generative models module

# %%
# Define project information
PROJECT_ID = "qwiklabs-gcp-03-0e7cdd399682"  # @param {type:"string"}
LOCATION = "us-central1"  # @param {type:"string"}

# Initialize Vertex AI
import vertexai

vertexai.init(project=PROJECT_ID, location=LOCATION)

# %% [markdown]
# 4. Initialize Gen AI with your project ID and a location (you can use like `us-central1`).

# %%
# TODO: Insert the required steps here
from vertexai.generative_models import (
    GenerationConfig,
    GenerativeModel,
    HarmBlockThreshold,
    HarmCategory,
    Image,
    Part,
    SafetySetting,
)

# %% [markdown]
# 5. Instantiate a generative model and save it to the `generative_model` variable. For this notebook, use `gemini-2.0-flash` as your model version. When instantiating the model, pass a `generation_config` parameter with the temperature set to 0.

# %%
# TODO: Insantiate a "gemini-2.0-flash" model with a configured temperature of 0.
generative_model = GenerativeModel("gemini-2.0-flash-001")

# %% [markdown]
# 6. Complete the TODO's in this function, which you will use for the rest of the lab:

# %%
def print_response(prompt):

    # TODO: Complete this line to generate a response to the prompt:
    response = generative_model.generate_content(prompt)

    # TODO: Complete this line to print only the text of the model's response,
    # not the additional response metadata.
    print(response.text)
    print()
# Example usage
print_response("Why is the sky blue?")
# Out:
# The sky appears blue due to a phenomenon called **Rayleigh scattering**. Here's the breakdown:
#
# * **Sunlight and its colors:** Sunlight is actually made up of all the colors of the rainbow.  These colors each have different wavelengths.  Red light has a longer wavelength, while blue and violet light have shorter wavelengths.
#
# * **Earth's Atmosphere:**  The Earth's atmosphere is full of tiny particles, mostly nitrogen and oxygen molecules.
#
# * **Scattering:** When sunlight enters the Earth's atmosphere, it collides with these air molecules. This collision causes the light to scatter in different directions.
#
# * **Rayleigh Scattering (the Key):**  Rayleigh scattering is more effective at scattering shorter wavelengths of light (blue and violet) than longer wavelengths (red and orange). This is because the scattering efficiency is inversely proportional to the fourth power of the wavelength.  (Think of it as the shorter wavelengths bouncing off more easily.)
#
# * **Why we see blue, not violet:** Although violet light has an even shorter wavelength than blue light, and therefore is scattered even more, the sun emits less violet light than blue light. Additionally, our eyes are more sensitive to blue light than violet light.  Also, violet light is absorbed more by the upper atmosphere. So, while violet *is* scattered a lot, the combination of less violet in sunlight, more absorption, and our eye sensitivity makes blue the dominant color we perceive.
#
# **In short:**
#
# Sunlight hits the atmosphere. Blue light is scattered much more than other colors because of its shorter wavelength. This scattered blue light reaches our eyes from all directions, making the sky appear blue.
#
# **Think of it like this:**
#
# Imagine throwing tennis balls (blue light) and basketballs (red light) at a bunch of obstacles. The tennis balls will bounce off in all directions much more easily than the basketballs, which will mostly keep going straight.
#
# That's why the sky is blue!

# %% [markdown]
# ## Task 2. Personas
#
# 1. Run the following cell to see the default response to this prompt.
#
# 2. Then tweak the prompt by asking the model to take on the persona of an **energetic, inspiring personal trainer** who can get users **excited to work out their leg muscles**. Note the difference in vocabulary and tone.

# %%
# TODO: Improve the personality of the response by assigning the suggested persona.

prompt = "What are some good leg exercises?"

print_response(prompt)

tweaked_response = "As an energetic and inspiring personal trainer, can you recommend some awesome leg exercises that will get me pumped and excited to crush my workout?"

print_response(tweaked_response)
# Out:
# Okay, let's break down some effective leg exercises, categorized for different fitness goals and levels.  I'll provide variations and tips too!
#
# **I. Foundational Compound Exercises (These work multiple muscle groups and are essential for building strength and muscle mass):**
#
# *   **Squats:** The king of leg exercises!
#     *   **Muscles Worked:** Quads, Hamstrings, Glutes, Core (Stabilizers)
#     *   **Variations:**
#         *   **Bodyweight Squat:** Great for beginners. Focus on form: feet shoulder-width apart, chest up, core engaged, descend as if sitting in a chair, keeping your back straight and knees behind your toes.
#         *   **Goblet Squat:** Hold a dumbbell or kettlebell close to your chest.  Helps with balance and core engagement.
#         *   **Front Squat:** Barbell across the front of your shoulders.  Targets quads more directly. Requires good mobility.
#         *   **Back Squat (High Bar/Low Bar):** Barbell across your upper back. The most common squat variation for strength training. High bar is more quad-focused, low bar more glute and hamstring focused.
#         *   **Overhead Squat:** Barbell overhead, requires significant mobility and stability. Very challenging.
#         *   **Jump Squat:** Explosive movement, adds a plyometric element for power.
#     *   **Tips:**
#         *   Focus on good form first.  Don't add weight until you can perform the movement correctly.
#         *   Control your descent.
#         *   Drive through your heels to stand back up.
#         *   Maintain a neutral spine.
#
# *   **Deadlifts:** A full-body exercise with significant leg involvement.
#     *   **Muscles Worked:** Hamstrings, Glutes, Lower Back, Quads (secondary), Core
#     *   **Variations:**
#         *   **Conventional Deadlift:** Standard stance, feet hip-width apart, hands outside of your legs.
#         *   **Sumo Deadlift:** Wider stance, hands inside of your legs. Often easier on the lower back.
#         *   **Romanian Deadlift (RDL):** Focuses on hamstring and glute activation.  Keep legs mostly straight with a slight bend at the knee.  Hinge at the hips, lowering the weight while maintaining a straight back.
#         *   **Trap Bar Deadlift:** Uses a trap bar, which is easier on the lower back for some people.
#     *   **Tips:**
#         *   Maintain a straight back throughout the entire movement.
#         *   Engage your lats (back muscles) to keep the bar close to your body.
#         *   Drive through your heels to lift the weight.
#         *   Don't round your back.
#         *   Start with lighter weight to master the form.
#
# *   **Lunges:** Great for unilateral (one leg at a time) strength and balance.
#     *   **Muscles Worked:** Quads, Hamstrings, Glutes
#     *   **Variations:**
#         *   **Forward Lunge:** Step forward into a lunge.
#         *   **Reverse Lunge:** Step backward into a lunge. Often easier on the knees.
#         *   **Walking Lunge:** Lunge forward, then bring your back leg through to step forward into another lunge.
#         *   **Lateral Lunge:** Step to the side into a lunge. Targets inner and outer thighs.
#         *   **Curtsy Lunge:** Step back and across your body. Targets glute medius.
#         *   **Bulgarian Split Squat:** Back foot elevated on a bench. Very challenging and effective.
#     *   **Tips:**
#         *   Keep your front knee behind your toes.
#         *   Maintain a straight back and engaged core.
#         *   Lower your back knee towards the ground, but don't slam it.
#         *   Push off with your front heel to return to the starting position.
#
# **II. Isolation Exercises (These focus on specific muscle groups):**
#
# *   **Hamstring Curls (Machine or Banded):**
#     *   **Muscles Worked:** Hamstrings
#     *   **Tips:** Control the movement and avoid swinging. Focus on squeezing your hamstrings.
#
# *   **Leg Extensions (Machine):**
#     *   **Muscles Worked:** Quads (primarily the rectus femoris)
#     *   **Tips:** Control the movement and avoid locking out your knees at the top.
#
# *   **Calf Raises (Standing or Seated):**
#     *   **Muscles Worked:** Calves (gastrocnemius and soleus)
#     *   **Variations:** Standing (targets gastrocnemius), Seated (targets soleus)
#     *   **Tips:** Focus on a full range of motion, squeezing your calves at the top.
#
# *   **Glute Bridges/Hip Thrusts:**
#     *   **Muscles Worked:** Glutes, Hamstrings
#     *   **Variations:**
#         *   **Glute Bridge:** Lie on your back, knees bent, feet flat on the floor.  Lift your hips off the ground, squeezing your glutes at the top.
#         *   **Hip Thrust:** Back elevated on a bench. Allows for a greater range of motion and heavier weight.
#         *   **Single-Leg Glute Bridge/Hip Thrust:** More challenging, improves balance.
#     *   **Tips:** Squeeze your glutes at the top of the movement. Keep your core engaged.
#
# *   **Adductor/Abductor Machine Exercises:**
#     *   **Muscles Worked:** Inner (adductors) and Outer (abductors) Thighs
#     *   **Tips:** Use controlled movements and focus on feeling the targeted muscles working.
#
# **III. Plyometric Exercises (Explosive movements for power and athleticism):**
#
# *   **Box Jumps:** Jump onto a box.
# *   **Jump Squats:** Explode upwards from a squat.
# *   **Lunge Jumps:** Jump between lunges.
# *   **Plyometric Lunges:** Explosive lunges.
# *   **Skater Jumps:** Lateral jumps, mimicking ice skating.
#
# **IV. Considerations for Building a Leg Workout:**
#
# *   **Choose a variety of exercises:**  Don't just stick to squats.  Include compound and isolation exercises to target all the muscles in your legs.
# *   **Consider your goals:**
#     *   **Strength:** Focus on lower reps (3-6) with heavier weight on compound exercises.
#     *   **Muscle Growth (Hypertrophy):** Focus on moderate reps (8-12) with moderate weight.
#     *   **Endurance:** Focus on higher reps (15-20+) with lighter weight.
# *   **Warm-up:** Start with light cardio and dynamic stretching (e.g., leg swings, hip circles) to prepare your muscles for exercise.
# *   **Cool-down:** Finish with static stretching (holding stretches for 30 seconds) to improve flexibility and reduce muscle soreness.
# *   **Listen to your body:** Don't push yourself too hard, especially when starting out.  Rest and recover when needed.
# *   **Proper form is crucial:** Prioritize form over weight.  If you're unsure about proper form, consider working with a qualified trainer.
# *   **Progressive overload:** Gradually increase the weight, reps, or sets over time to continue challenging your muscles.
# *   **Frequency:** Aim for 2-3 leg workouts per week, with at least one day of rest in between.
# *   **Sample Workout:** This is just an example, adjust based on your fitness level and goals.
#
#     *   Warm-up: 5 minutes of light cardio and dynamic stretching
#     *   Back Squats: 3 sets of 8-12 reps
#     *   Romanian Deadlifts: 3 sets of 10-15 reps
#     *   Lunges: 3 sets of 10-12 reps per leg
#     *   Leg Extensions: 3 sets of 12-15 reps
#     *   Hamstring Curls: 3 sets of 12-15 reps
#     *   Calf Raises: 3 sets of 15-20 reps
#     *   Cool-down: Static stretching (hamstring stretch, quad stretch, calf stretch)
#
# **Important Note:** If you have any pre-existing injuries or medical conditions, consult with a doctor or physical therapist before starting any new exercise program.
#
# Let me know if you have any more questions or want me to tailor a workout to a specific goal!
#
#
# Alright, let's get those legs PUMPED and those endorphins flowing! Forget boring squats, we're going for POWER, BURN, and RESULTS! Here's a leg workout designed to get you fired up and ready to conquer:
#
# **Warm-Up (5-10 minutes - dynamic stretches are key!)**
#
# *   **Leg Swings (Forward & Lateral):** Get those hips and hamstrings moving. Feel the stretch!
# *   **High Knees:** Drive those knees up, engage the core.
# *   **Butt Kicks:** Kick those heels up to your glutes.
# *   **Walking Lunges:** Nice and controlled, focus on form.
# *   **Bodyweight Squats:** Just a few to wake up the quads and glutes.
#
# **The Workout (Choose 3-4 exercises, 3-4 sets of 8-12 reps each. Adjust weight accordingly to challenge yourself!)**
#
# 1.  **Jump Squats (Explosive Power!):**
#     *   Why it's awesome: This is your POWER move! Explode upwards, engaging those quads, glutes, and calves. The jump adds an extra layer of intensity and gets the heart pumping.
#     *   Focus: Control the landing, and sink right back into the squat. Land softly. Visualize yourself jumping higher with each rep!
#     *   Progression: If bodyweight isn't enough, hold a dumbbell or wear a weight vest.
#
# 2.  **Bulgarian Split Squats (Balance and Burn!):**
#     *   Why it's awesome: Unilateral training builds strength, balance, and stability. The burn in your working leg is INTENSE.  This helps prevent imbalances and target your glutes!
#     *   Focus: Keep your front knee behind your toes, core engaged. Imagine driving through your front heel.
#     *   Progression: Hold dumbbells for extra resistance.
#
# 3.  **Walking Lunges with a Twist (Core and Leg Activation!):**
#     *   Why it's awesome: Walking lunges are already great, but adding a twist engages your core and obliques for a full-body workout.  Feel that burn!
#     *   Focus: Keep your back straight, core tight, and twist towards the front leg. Maintain balance.
#     *   Progression: Hold a medicine ball or dumbbell and twist with it.
#
# 4.  **Romanian Deadlifts (RDLs) (Posterior Chain Power!):**
#     *   Why it's awesome: Hits your hamstrings, glutes, and lower back HARD. Focus on a controlled descent and feel the stretch in your hamstrings. Proper form is essential!
#     *   Focus: Keep your back straight, hinge at the hips, and lower the weight while maintaining a slight bend in your knees. Squeeze your glutes to return to the starting position.
#     *   Progression: Increase the weight as you get stronger.
#
# 5.  **Leg Press (Heavy Hitter!):**
#     *   Why it's awesome: Allows you to load up with HEAVY weight!  A great way to build overall leg strength and power.
#     *   Focus: Keep your back pressed against the pad, maintain a controlled range of motion, and push through your heels.
#     *   Progression: Increase weight gradually.
#
# 6.  **Hamstring Curls (Isolation Power!):**
#     *   Why it's awesome: Allows you to focus on the Hamstrings! Feel that muscle working to curl those legs back!
#     *   Focus: Control is key, contract and return slowly!
#     *   Progression: Increase weight to challenge your hamstring strength!
#
# **Finisher (Choose one to really feel the burn!)**
#
# *   **Glute Bridges (Glute Activation!):**  Squeeze those glutes at the top of each rep. Can be done with or without weight.  Hold the top position for 2 seconds for maximum burn.
# *   **Calf Raises (Calf Definition!):**  Pump those calves until they are screaming!
# *   **30 Second Plank (Core Engaged):** Finish strong by holding plank for 30 seconds!
#
# **Cool-Down (5-10 minutes - static stretches)**
#
# *   Hold each stretch for 30 seconds.
# *   Quad Stretch, Hamstring Stretch, Calf Stretch, Glute Stretch
#
# **Tips for Motivation and Success:**
#
# *   **Visualize Success:** Before you start, imagine yourself crushing the workout, feeling strong and energized.
# *   **Music is Key:** Create a playlist that pumps you up and keeps you moving.
# *   **Track Your Progress:** Write down your weights and reps each workout to see how you're improving.  This is a huge motivator!
# *   **Listen to Your Body:** Don't push yourself too hard, especially if you're new to these exercises. Focus on form first.
# *   **Fuel Your Body:** Eat a healthy meal or snack before and after your workout.
# *   **Celebrate Your Wins:**  Acknowledge your hard work and dedication.
#
# **Important Considerations:**
#
# *   **Proper Form is Paramount:** Watch videos and practice the correct form before adding weight.
# *   **Warm-up and Cool-down:** Don't skip these crucial steps to prevent injuries.
# *   **Progression:** Gradually increase the weight, reps, or sets as you get stronger.
# *   **Listen to Your Body:** Rest when you need to and don't push through pain.
# *   **Consult a Professional:** If you have any concerns or injuries, consult with a doctor or physical therapist before starting a new exercise program.
#
# Now get out there and CRUSH it!  Remember to stay focused, stay energized, and believe in yourself! You've got this! I'm here to cheer you on! Let me know how it goes!

# %% [markdown]
# ## Task 3. Be specific + constrain the output format
#
# 1. Have the model convert the following text of cooking ingredients to a YAML format. Each ingredient should be listed as a dictionary with keys for **ingredient** and **quantity** populated with the correct value given the ingredients in the following recipe:

# %%
# TODO: Write instructions to complete the task.
instructions = """
Convert the list of cooking ingredients below into a YAML format. 
Each ingredient should be represented as a dictionary with two keys: 
- 'ingredient': the name of the ingredient 
- 'quantity': the amount and unit of the ingredient 

Return only the YAML list with no extra text or explanation.
"""

ingredients = """
    Ingredients:
    * 9 egg whites
    * 3/8 tsp Cream of Tartar
    * 1 1/2 tbs Vinegar
    * 1 1/2 tsp Vanilla
    * 3 cups Sugar
    * 1 quarts Heavy whipping cream
    * 3 boxes Strawberries
    """

prompt = instructions + "\n\n" + ingredients

print_response(prompt)
# Out:
# ```yaml
# - ingredient: egg whites
#   quantity: 9
# - ingredient: Cream of Tartar
#   quantity: 3/8 tsp
# - ingredient: Vinegar
#   quantity: 1 1/2 tbs
# - ingredient: Vanilla
#   quantity: 1 1/2 tsp
# - ingredient: Sugar
#   quantity: 3 cups
# - ingredient: Heavy whipping cream
#   quantity: 1 quarts
# - ingredient: Strawberries
#   quantity: 3 boxes
# ```

# %% [markdown]
# ## Task 4. Use a fallback response
#
# 1. Adjust the prompt below to specify that the model should only answer questions related to historical landmarks. If a user askes about something else, the model should respond with the message: `Sorry, I only answer questions about historical landmarks!`
#
# 2. Adjust your instructions until the model declines to answer the `user_query` below.

# %%
# TODO: Add instructions to prompt a fallback response for off-topic queries.
# Instructions to limit the response to historical landmarks and provide a fallback for off-topic queries
instructions = (
    "You are a history tour guide. You only answer questions related to historical landmarks. "
    "If the question is about something else, respond with: 'Sorry, I only answer questions about historical landmarks!' "
    "Answer the user's question: {user_query}"
)

user_query = "How can I attract butterflies to my garden?"

# Print the response based on the adjusted prompt
print_response(instructions.format(user_query=user_query))
# Out:
# Sorry, I only answer questions about historical landmarks!

# %% [markdown]
# ## Task 5. Make results more specific with examples
#
# 1. Run the code cell below to see the model's response as-is.
#
# 2. Imagining you work for a bicycle tour company, modify each of the example outputs below to include a bicycle.
#
# 3. Re-run the code cell to make sure the model generates a bicycle-themed response. Leave the instructions alone and tweak your examples until you get such a response.

# %%
prompt = """
    <INSTRUCTIONS>
    Give a tourist recommendation for the input city, ensuring to include a bicycle in the activity.
    </INSTRUCTIONS>

    <EXAMPLES>
    Input: Paris
    Output: Rent a bicycle and ride along the Seine, stopping at the Louvre and then cycling up to Montmartre for a scenic view.

    Input: Washington D.C.
    Output: Rent a bike to cycle to the Lincoln Memorial, and enjoy the ride along the National Mall while visiting the monuments.

    Input: New York City
    Output: Rent a bicycle and explore Central Park, then ride along the Hudson River Greenway, stopping at waterfront parks.
    </EXAMPLES>

    <INPUT CITY>
    Bangalore
    </INPUT CITY>"""

print_response(prompt)
# Out:
# Rent a bicycle and explore Cubbon Park, then cycle through the leafy avenues of Bangalore's older neighborhoods like Malleswaram and Basavanagudi, soaking in the city's unique blend of tradition and modernity.

# %%
# TODO: Modify the examples below to guide the model to always generate
# recommendations involving bicycles.

prompt = """
    <INSTRUCTIONS>
    Give a tourist recommendation for the input city.
    </INSTRUCTIONS>

    <EXAMPLES>
    Input: Paris
    Output: Take a taxi to the Louvre and then to Montmartre.

    Input: Washington D.C.
    Output: Drive your rental car to the Lincoln Memorial.

    Input: New York City
    Output: Walk along the river.
    </EXAMPLES>

    <INPUT CITY>
    Bangalore
    </INPUT CITY>"""

print_response(prompt)
# Out:
# Take a rickshaw to Cubbon Park.

# %% [markdown]
# ## Congratulations!
#
# If you have completed the steps above, you have demonstrated your ability to use several prompt engineering techniques.
