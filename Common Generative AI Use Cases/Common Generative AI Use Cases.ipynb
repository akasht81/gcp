# %%
# %pip install --upgrade --quiet google-cloud-aiplatform
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 42.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-server 1.24.0 requires anyio<4,>=3.1.0, but you have anyio 4.9.0 which is incompatible.

# %%
from inspect import cleandoc
from IPython.display import display, Markdown

import vertexai
from vertexai.generative_models import GenerativeModel, GenerationConfig

# %%
PROJECT = !gcloud config get-value project
PROJECT_ID = PROJECT[0]
REGION = "us-central1"
vertexai.init(project=PROJECT_ID, location=REGION)

# %%
model = GenerativeModel("gemini-2.0-flash-001")

# %%
creative_gen_config = GenerationConfig(temperature=1, top_p=0.8)

# %%
prompt = "What are some strategies for overcoming writer's block?"

response = model.generate_content(prompt,
                                  generation_config=creative_gen_config)
print(response.text)
# Out:
# Writer's block is a frustrating experience, but thankfully, there are many strategies to overcome it. Here's a breakdown of effective techniques, categorized for easier understanding:
#
# **I. Shifting Your Mindset:**
#
# *   **Lower the Stakes:** Stop aiming for perfection right away. Remind yourself that the first draft is just that – a draft. It's okay to be messy and imperfect. Focus on getting something down on paper.
# *   **Embrace Imperfection:**  "Done is better than perfect."  Don't let the fear of writing something bad stop you from writing anything at all. You can always edit and revise later.
# *   **Reframe the Task:** Instead of "writing," think of it as "brainstorming," "exploring," or "talking to yourself on paper."  This can make the process feel less daunting.
# *   **Identify the Fear:** What are you afraid of? Is it failure? Criticism? Not being good enough?  Naming the fear can help you address it.
# *   **Give Yourself Permission to Write Badly:** Seriously.  Write the worst possible version of what you're trying to write.  This can be surprisingly liberating.
# *   **Remember Your "Why":** Why are you writing this in the first place?  Connecting with your passion and purpose can reignite your motivation.
# *   **Be Kind to Yourself:** Writer's block is normal.  Don't beat yourself up about it.  Acknowledge it, and then try some of these strategies.
#
# **II. Changing Your Environment & Routine:**
#
# *   **Change Your Location:**  Move to a different room, a coffee shop, a library, or even outside. A change of scenery can spark new ideas.
# *   **Change Your Time:**  Try writing at a different time of day. Are you a morning person?  An evening person? Experiment to find your optimal writing time.
# *   **Change Your Tools:** Switch from your computer to a notebook and pen, or vice versa.  Sometimes a different medium can break the block.
# *   **Take a Break:** Step away from the writing completely. Go for a walk, exercise, listen to music, or do something you enjoy.  Sometimes your brain just needs a rest.
# *   **Set a Timer:** Commit to writing for a specific amount of time (e.g., 25 minutes) without any distractions.  The Pomodoro Technique can be very effective.
# *   **Create a Ritual:** Establish a pre-writing routine to signal to your brain that it's time to write. This could involve making a cup of tea, listening to specific music, or doing some stretching.
#
# **III. Generating Ideas & Content:**
#
# *   **Freewriting:** Write continuously for a set amount of time (e.g., 10-15 minutes) without stopping to edit or censor yourself. Just let your thoughts flow onto the page.
# *   **Brainstorming:**  Write down every idea that comes to mind, no matter how silly or irrelevant it may seem.  Don't judge or evaluate at this stage.
# *   **Mind Mapping:**  Create a visual representation of your ideas, connecting related concepts with lines and branches.
# *   **Outlining:**  Create a structured outline of your piece, breaking it down into smaller, more manageable sections.
# *   **Research:**  Read articles, books, or websites related to your topic.  Sometimes new information can spark new ideas.
# *   **Talk It Out:**  Discuss your writing project with a friend, family member, or colleague.  Talking about it can help you clarify your thoughts and generate new ideas.
# *   **Ask Questions:**  What are the key questions you're trying to answer in your writing?  Focus on answering those questions, one at a time.
# *   **Start in the Middle:**  If you're stuck on the beginning, try writing a scene from the middle or end of your piece.
# *   **Write a Different Section:**  If you're blocked on one section, move on to another section that you feel more confident about.
# *   **Use Prompts:**  Find writing prompts online or in books to spark your creativity.
# *   **Imagine Your Audience:**  Who are you writing for?  What do they need to know?  Writing for a specific audience can help you focus your ideas.
# *   **Look at Other People's Work:** Read something similar to what you're trying to write.  See how other authors have approached the topic.  (But avoid direct copying!)
# *   **Summarize Existing Material:** Take a concept or piece of information and summarize it in your own words.  This can help you understand it better and generate new insights.
#
# **IV. Breaking Down the Task:**
#
# *   **Focus on One Small Task:** Instead of trying to write the entire piece at once, break it down into smaller, more manageable tasks.  For example, "Write one paragraph," or "Write the introduction."
# *   **Set Realistic Goals:** Don't try to write a novel in a day.  Set small, achievable goals for each writing session.
# *   **Reverse Outlining:**  If you already have some writing, create an outline based on what you've written. This can help you identify gaps and areas that need more development.
# *   **Chunking:**  Break down large blocks of text into smaller, more digestible chunks. This can make the writing process feel less overwhelming.
#
# **V.  Dealing with Specific Blocks:**
#
# *   **Stuck on the Beginning:**  Write the introduction last.  Or, write several different introductions and choose the best one.
# *   **Stuck on a Specific Scene:**  Skip it and come back to it later.  Or, try writing the scene from a different character's point of view.
# *   **Stuck on Dialogue:**  Record yourself having a conversation about the topic.  Transcribe the conversation and use it as a starting point for your dialogue.
#
# **Key Takeaways:**
#
# *   **Experiment:**  Not every strategy will work for everyone.  Experiment with different techniques to find what works best for you.
# *   **Be Patient:**  Overcoming writer's block takes time and effort.  Don't get discouraged if you don't see results immediately.
# *   **Practice:**  The more you write, the easier it will become to overcome writer's block.
#
# By consistently applying these strategies, you can significantly reduce the frequency and severity of writer's block and get back to enjoying the writing process. Good luck!

# %%
prompt = "Provide ten interview questions for the role of prompt engineer."

response = model.generate_content(prompt,
                                  generation_config=creative_gen_config)
print(response.text)
# Out:
# Okay, here are ten interview questions for a Prompt Engineer role, covering a range of skills and knowledge required for the position:
#
# **Technical Proficiency & Understanding:**
#
# 1.  **Describe your experience with different Large Language Models (LLMs) like GPT-3, LaMDA, or others. What are the strengths and weaknesses of each in your opinion, and how does that impact your prompt engineering strategy?**
#     *   *Why this question?*  This assesses the candidate's hands-on experience and understanding of the nuances of different models, which is crucial for tailoring prompts effectively. It also gauges their critical thinking.
#
# 2.  **Explain the concept of "prompt engineering." What are the key techniques you use to craft effective prompts, and can you provide examples of when you would choose one technique over another (e.g., few-shot learning, chain-of-thought prompting, role-playing)?**
#     *   *Why this question?*  This tests the candidate's foundational knowledge of prompt engineering principles and their ability to apply them practically. It also explores their understanding of various prompting methodologies.
#
# 3.  **How do you approach debugging or troubleshooting a prompt that is consistently producing undesirable or inaccurate results? What tools or methods do you employ to analyze the prompt and the model's output?**
#     *   *Why this question?*  This explores the candidate's problem-solving skills and their ability to systematically identify and address issues in prompt design.  It reveals their debugging methodology.
#
# **Practical Application & Creativity:**
#
# 4.  **Imagine you're tasked with building a prompt to help an LLM generate creative short stories.  Describe your initial approach, including the prompt structure, the types of constraints you might include, and how you would iterate on the prompt based on initial outputs.**
#     *   *Why this question?*  This assesses the candidate's ability to translate a high-level objective into a concrete prompt design and their understanding of the iterative process of prompt development.
#
# 5.  **We need to build a prompt that can extract specific information from a long, unstructured text document (e.g., key entities, dates, relationships).  How would you design this prompt, and what challenges do you anticipate in achieving accurate and reliable information extraction?**
#     *   *Why this question?*  This tests the candidate's ability to apply prompt engineering to a specific, practical task (information extraction) and their awareness of potential pitfalls.
#
# **Understanding of Limitations & Ethics:**
#
# 6.  **LLMs can sometimes generate biased or harmful content. How do you design prompts to mitigate these risks? What techniques do you use to ensure that the model's output is ethical, unbiased, and aligned with safety guidelines?**
#     *   *Why this question?*  This is critical. It assesses the candidate's awareness of the ethical implications of LLMs and their commitment to responsible prompt engineering.  It also tests their ability to implement safeguards.
#
# 7.  **What are the limitations of current LLMs and how do those limitations affect your approach to prompt engineering? How do you manage user expectations regarding what an LLM can and cannot do?**
#     *   *Why this question?*  This tests the candidate's realistic understanding of LLM capabilities and their ability to set appropriate expectations for users.  It shows they understand the scope and boundaries of LLMs.
#
# **Communication & Collaboration:**
#
# 8.  **Describe a time you had to explain a complex technical concept related to LLMs or prompt engineering to a non-technical audience. How did you approach it, and what were the key takeaways you wanted them to understand?**
#     *   *Why this question?*  This assesses the candidate's communication skills and their ability to bridge the gap between technical expertise and broader understanding.
#
# 9.  **How would you collaborate with a team of developers and product managers to integrate your prompt engineering work into a larger software application? What communication strategies would you use to ensure that the prompts are effectively utilized and maintained?**
#     *   *Why this question?*  This explores the candidate's ability to work effectively in a team environment and their understanding of the software development lifecycle.
#
# **Future-Oriented & Learning:**
#
# 10. **The field of prompt engineering is rapidly evolving. How do you stay up-to-date with the latest research, techniques, and best practices? What are some emerging trends in prompt engineering that you find particularly exciting or promising?**
#     *   *Why this question?*  This demonstrates the candidate's commitment to continuous learning and their awareness of the evolving landscape of LLMs and prompt engineering.  It shows their passion for the field.
#
# These questions provide a good starting point for assessing a candidate's suitability for a Prompt Engineer role. Remember to tailor the questions to the specific requirements of your organization and the specific tasks the prompt engineer will be responsible for. Good luck!

# %%
predictable_gen_config = GenerationConfig(temperature=0.1, top_p=0.1)

# %%
prompt = """
Given a user's input, classify their intent, such as "finding information", "making a reservation", or "placing an order". \n
user input: Hi, can you please book a table for two at Juan for May 1?
"""

response = model.generate_content(
    prompt, generation_config=predictable_gen_config
)
print(response.text)
# Out:
# Making a reservation.

# %%
prompt = """
What is the topic for a given news headline? \n
- business \n
- entertainment \n
- health \n
- sports \n
- technology \n\n

Text: Pixel 7 Pro Expert Hands On Review. \n
The answer is: technology \n

Text: Quit smoking? \n
The answer is: health \n

Text: Birdies or bogeys? Top 5 tips to hit under par \n
The answer is: sports \n

Text: Relief from local minimum-wage hike looking more remote \n
The answer is: business \n

Text: You won't guess who just arrived in Bari, Italy for the movie premiere. \n
The answer is:
"""

response = model.generate_content(
    prompt, generation_config=predictable_gen_config
)
print(response.text)
# Out:
# entertainment

# %%
import pandas as pd
from sklearn.metrics import classification_report

review_data_df = pd.DataFrame(
    {
        "review": [
            "i love this product. it does have everything i am looking for!",
            "all i can say is that you will be happy after buying this product",
            "its way too expensive and not worth the price",
            "i am feeling okay. its neither good nor too bad.",
        ],
        "sentiment_groundtruth": ["positive", "positive", "negative", "neutral"],
    }
)

review_data_df
# Out:
#                                               review sentiment_groundtruth
# 0  i love this product. it does have everything i...              positive
# 1  all i can say is that you will be happy after ...              positive
# 2      its way too expensive and not worth the price              negative
# 3   i am feeling okay. its neither good nor too bad.               neutral

# %%
def get_sentiment(row):
    prompt = f"""Classify the sentiment of the following review as "positive", "neutral" or "negative". Return only the classification.
                review: {row}
              """
    response = model.generate_content(
        contents=prompt, generation_config=predictable_gen_config
    ).text
    return response


review_data_df["sentiment_prediction"] = review_data_df["review"].apply(get_sentiment)
review_data_df
# Out:
#                                               review sentiment_groundtruth  \
# 0  i love this product. it does have everything i...              positive
# 1  all i can say is that you will be happy after ...              positive
# 2      its way too expensive and not worth the price              negative
# 3   i am feeling okay. its neither good nor too bad.               neutral
#
#   sentiment_prediction
# 0           positive\n
# 1           positive\n
# 2           negative\n
# 3            Neutral\n

# %%
report = classification_report(
    review_data_df["sentiment_groundtruth"], review_data_df["sentiment_prediction"]
)
Markdown(report)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#     Neutral
#        0.00      0.00      0.00       0.0
#     negative       0.00      0.00      0.00       1.0
#    negative
#        0.00      0.00      0.00       0.0
#      neutral       0.00      0.00      0.00       1.0
#     positive       0.00      0.00      0.00       2.0
#    positive
#        0.00      0.00      0.00       0.0
#
#     accuracy                           0.00       4.0
#    macro avg       0.00      0.00      0.00       4.0
# weighted avg       0.00      0.00      0.00       4.0

# %%
predictable_gen_config = GenerationConfig(temperature=0.1, top_p=0.1)

# %%
prompt = """
Provide a very short summary, no more than three sentences, for the following article:

Our quantum computers work by manipulating qubits in an orchestrated fashion that we call quantum algorithms.
The challenge is that qubits are so sensitive that even stray light can cause calculation errors — and the problem worsens as quantum computers grow.
This has significant consequences, since the best quantum algorithms that we know for running useful applications require the error rates of our qubits to be far lower than we have today.
To bridge this gap, we will need quantum error correction.
Quantum error correction protects information by encoding it across multiple physical qubits to form a "logical qubit," and is believed to be the only way to produce a large-scale quantum computer with error rates low enough for useful calculations.
Instead of computing on the individual qubits themselves, we will then compute on logical qubits. By encoding larger numbers of physical qubits on our quantum processor into one logical qubit, we hope to reduce the error rates to enable useful quantum algorithms.

Summary:

"""

response = model.generate_content(
    prompt, generation_config=predictable_gen_config
)
print(response.text)
# Out:
# Quantum computers are currently limited by high error rates due to qubit sensitivity. Quantum error correction, which encodes information across multiple physical qubits to form a more stable "logical qubit," is necessary to reduce these errors. This approach is crucial for enabling large-scale, useful quantum computations.

# %%
prompt = """
Provide a very short summary in four bullet points for the following article:

Our quantum computers work by manipulating qubits in an orchestrated fashion that we call quantum algorithms.
The challenge is that qubits are so sensitive that even stray light can cause calculation errors — and the problem worsens as quantum computers grow.
This has significant consequences, since the best quantum algorithms that we know for running useful applications require the error rates of our qubits to be far lower than we have today.
To bridge this gap, we will need quantum error correction.
Quantum error correction protects information by encoding it across multiple physical qubits to form a "logical qubit," and is believed to be the only way to produce a large-scale quantum computer with error rates low enough for useful calculations.
Instead of computing on the individual qubits themselves, we will then compute on logical qubits. By encoding larger numbers of physical qubits on our quantum processor into one logical qubit, we hope to reduce the error rates to enable useful quantum algorithms.

Bullet points:

"""

response = model.generate_content(
    contents=prompt, generation_config=predictable_gen_config
)
Markdown(response.text)
# Out:
# Here's a four-bullet-point summary:
#
# *   Quantum computers use qubits, which are highly susceptible to errors.
# *   Current error rates are too high for running useful quantum algorithms.
# *   Quantum error correction, using "logical qubits," is needed to reduce errors.
# *   Logical qubits encode information across multiple physical qubits for improved accuracy.

# %%
prompt = """
Please generate a summary of the following conversation and at the end summarize the to-do's for the support Agent:

Customer: Hi, I'm Larry, and I received the wrong item.

Support Agent: Hi, Larry. How would you like to see this resolved?

Customer: That's alright. I want to return the item and get a refund, please.

Support Agent: Of course. I can process the refund for you now. Can I have your order number, please?

Customer: It's [ORDER NUMBER].

Support Agent: Thank you. I've processed the refund, and you will receive your money back within 14 days.

Customer: Thank you very much.

Support Agent: You're welcome, Larry. Have a good day!

Summary:
"""

response = model.generate_content(
    contents=prompt, generation_config=predictable_gen_config
)
Markdown(response.text)
# Out:
# Larry contacted support because he received the wrong item and wants to return it for a refund. The support agent offered to process the refund, obtained the order number, and confirmed the refund was processed, stating it would take up to 14 days to receive the money back.
#
# To-Do's for the Support Agent:
#
# *   **Ensure the refund was actually processed in the system.**
# *   **(Optional, but good practice) Follow up with Larry in 14 days to confirm he received the refund.**

# %%
order = "We need eight grilled cheese sandwiches. Two with swiss cheese, three with muenster, three with cheddar."

prompt = """
    Break the customer's order into individual items with keys for the following fields:
    - item_name
    - cheese_selection

    Order:
    {order_field}
""".format(order_field=order)

response = model.generate_content(
    contents=prompt, generation_config=predictable_gen_config
)
print(response.text)
# Out:
# ```json
# [
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Swiss"
#   },
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Swiss"
#   },
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Muenster"
#   },
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Muenster"
#   },
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Muenster"
#   },
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Cheddar"
#   },
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Cheddar"
#   },
#   {
#     "item_name": "Grilled Cheese Sandwich",
#     "cheese_selection": "Cheddar"
#   }
# ]
# ```

# %%
prompt = """Q: Who was President of the United States in 1955?
              Which party did he belong to?
            A:
        """
response = model.generate_content(
    contents=prompt, generation_config=predictable_gen_config
)
print(response.text)
# Out:
# A: Dwight D. Eisenhower
#    Republican Party

# %%
context = """
Storage and content policy \n
How durable is my data in Cloud Storage? \n
Cloud Storage is designed for 99.999999999% (11 9's) annual durability, which is appropriate for even primary storage and
business-critical applications. This high durability level is achieved through erasure coding that stores data pieces redundantly
across multiple devices located in multiple availability zones.
Objects written to Cloud Storage must be redundantly stored in at least two different availability zones before the
write is acknowledged as successful. Checksums are stored and regularly revalidated to proactively verify that the data
integrity of all data at rest as well as to detect corruption of data in transit. If required, corrections are automatically
made using redundant data. Customers can optionally enable object versioning to add protection against accidental deletion.
"""

question = "How is high availability achieved?"

prompt = f"""Answer the question given in the contex below:
Context: {context}?\n
Question: {question} \n
Answer:
"""

print("[Prompt]")
print(prompt)

print("[Response]")
response = model.generate_content(contents=prompt, generation_config=predictable_gen_config)
print(response.text)
# Out:
# [Prompt]
# Answer the question given in the contex below:
# Context:
# Storage and content policy
#
# How durable is my data in Cloud Storage?
#
# Cloud Storage is designed for 99.999999999% (11 9's) annual durability, which is appropriate for even primary storage and
# business-critical applications. This high durability level is achieved through erasure coding that stores data pieces redundantly
# across multiple devices located in multiple availability zones.
# Objects written to Cloud Storage must be redundantly stored in at least two different availability zones before the
# write is acknowledged as successful. Checksums are stored and regularly revalidated to proactively verify that the data
# integrity of all data at rest as well as to detect corruption of data in transit. If required, corrections are automatically
# made using redundant data. Customers can optionally enable object versioning to add protection against accidental deletion.
# ?
#
# Question: How is high availability achieved?
#
# Answer:
#
# [Response]
# High availability is achieved through erasure coding that stores data pieces redundantly across multiple devices located in multiple availability zones. Objects are redundantly stored in at least two different availability zones before a write is acknowledged as successful.
